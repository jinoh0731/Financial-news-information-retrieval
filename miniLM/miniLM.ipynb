# %% [markdown]
# ### Transformers Project - MiniLM
#
# The purpose of this notebook to use MiniLM to get the embeddings of our candidate (news article) and query (SASB industry topic) to then compute the consine similarity scores to do information retrieval.
#
# Since we are using an out-of-the-box MiniLM to get the embeddings, we only need the test_df_cleaned_no_stopwords datafile to get the respective model metrics.

# %%
import pandas as pd
df = pd.read_csv("test_df_cleaned_no_stopwords.csv")

# %%
df
# Out:
#                                       title_and_content Ticker  \
# 0     New York Cements Itself as the Gold Mining Cap...    NEM
# 1     Shareholders v. Tesla, Nasdaq's diversity rule...   NDAQ
# 2     FedEx closing more locations, planning to furl...    FDX
# 3     Modelo Maker Profits From Bud Light‚Äôs De...    STZ
# 4     Med tech investors paying up for patents - Med...   ILMN
# ...                                                 ...    ...
# 1036  Lockheed Martin Stumbles on Supply Chain - WSJ...    LMT
# 1037  Banks Rush To Borrow Record-Breaking $165 Bill...    BAC
# 1038  Ohio train derailment: Norfolk Southern CEO sa...    NSC
# 1039  AT&T, Verizon, and T-Mobile could avoid $200 m...      T
# 1040  Ford Making EVs Means Turning the Clock Back 1...      F
#
#                             Industry                     Company  \
# 0                    Metals & Mining                Newmont Corp
# 1     Security & Commodity Exchanges                  Nasdaq Inc
# 2            Air Freight & Logistics                  FedEx Corp
# 3                Alcoholic Beverages  Constellation Brands Inc A
# 4       Medical Equipment & Supplies                Illumina Inc
# ...                              ...                         ...
# 1036             Aerospace & Defence             Lockheed Martin
# 1037                Commercial Banks        Bank of America Corp
# 1038             Rail Transportation       Norfolk Southern Corp
# 1039      Telecommunication Services                    AT&T Inc
# 1040                     Automobiles               Ford Motor Co
#
#                                                    SASB GPT_ESG_or_not  \
# 0     {'Tailings Storage Facilities Management': 'Th...          Minor
# 1     {'Managing Conflicts of Interest': 'Security a...          Major
# 2     {'Greenhouse Gas Emissions': 'Air Freight & Lo...          Minor
# 3     {'Water Management': 'Water management include...          Minor
# 4     {'Product Safety': 'Information on product saf...          Minor
# ...                                                 ...            ...
# 1036  {'Product Safety': 'Product safety is an impor...          Major
# 1037  {'Factors in Credit Analysis': 'As financial i...          Major
# 1038  {'Greenhouse Gas Emissions': 'The Rail Transpo...          Major
# 1039  {'Competitive Behaviour & Open Internet': 'The...          Major
# 1040  {'Product Safety': 'Driving is a risky activit...          Major
#
#      GPT_firm_or_not GPT_sentiment  \
# 0              Major      Positive
# 1              Major      Negative
# 2              Major      Negative
# 3              Minor      Positive
# 4              Major      Negative
# ...              ...           ...
# 1036           Major      Negative
# 1037           Major      Negative
# 1038           Major      Negative
# 1039           Major      Negative
# 1040           Major       Neutral
#
#                                              GPT_topics ESG_or_not  \
# 0     Community Relations, Business Ethics & Transpa...         No
# 1     Managing Conflicts of Interest, Promoting Tran...      Major
# 2     Employee Health & Safety, Labour Practices, Su...      Minor
# 3     Water Management, Packaging Lifecycle Manageme...         No
# 4                                       Business Ethics         No
# ...                                                 ...        ...
# 1036                                 Materials Sourcing      Major
# 1037          Systemic Risk Management, Business Ethics      Major
# 1038  Accident & Safety Management, Employee Health ...      Major
# 1039                        Data Privacy, Data Security      Major
# 0     tailings storage facilities management - the m...
# 1     managing conflicts of interest - security and ...
# 2     greenhouse gas emissions - air freight & logis...
# 3     water management - water management includes a...
# 4     product safety - information on product safety...
# ...                                                 ...
# 1036  product safety - product safety is an importan...
# 1037  factors in credit analysis - as financial inte...
# 1038  greenhouse gas emissions - the rail transporta...
# 1039  competitive behaviour & open internet - the te...
# 1040  product safety - driving is a risky activity, ...
#
#                                                 cw_text  \
# 0     new york cements gold mining capital world new...
# 1     shareholders v. tesla nasdaq diversity rule se...
# 2     fedex closing locations planning furlough empl...
# 3     modelo maker profits bud light⊚Öôs decline...
# 4     med tech investors paying patents med tech sta...
# ...                                                 ...
# 1036  lockheed martin stumbles supply chain wsj dema...
# 1037  banks rush borrow record breaking $ 165 billio...
# 1038  ohio train derailment norfolk southern ceo say...
# 1039  at&t verizon t mobile avoid $ 200 million fine...
# 1040  ford making evs means turning clock 100 years ...
#
#                                      cw_sasb_query_text
# 0     tailings storage facilities management metals ...
# 1     managing conflicts interest security commodity...
# 2     greenhouse gas emissions air freight logistics...
# 3     water management water management includes ent...
# 4     product safety information product safety effe...
# ...                                                 ...
# 1036  product safety product safety important consid...
# 1037  factors credit analysis financial intermediari...
# 1038  greenhouse gas emissions rail transportation i...
# 1039  competitive behaviour open internet telecommun...
# 1040  product safety driving risky activity factors ...
#
# [1041 rows x 20 columns]

# %%
import pandas as pd
import torch
import torch.nn.functional as F
from transformers import AutoTokenizer, AutoModel
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Function for mean pooling
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output.last_hidden_state
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)

# %%
# Load tokenizer and model from Hugging Face
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')
model = AutoModel.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')

# %%
# Function to encode text to embeddings
def encode_texts(texts):
    encoded_input = tokenizer(texts, padding=True, truncation=True, return_tensors='pt')
    with torch.no_grad():
        model_output = model(**encoded_input)
    return mean_pooling(model_output, encoded_input['attention_mask'])

# %%
df_test = df

# %%
# Generate embeddings for both queries and candidates
query_embeddings = encode_texts(df_test['cw_sasb_query_text'].tolist())
candidate_embeddings = encode_texts(df_test['cw_text'].tolist())

# %%
# Normalize embeddings
query_embeddings = F.normalize(query_embeddings, p=2, dim=1)
candidate_embeddings = F.normalize(candidate_embeddings, p=2, dim=1)

# %%
df_test['query_embedding'] = [emb.numpy().tolist() for emb in query_embeddings]
df_test['candidate_embedding'] = [emb.numpy().tolist() for emb in candidate_embeddings]

# %%
df_test
# Out:
#                                       title_and_content Ticker  \
# 0     New York Cements Itself as the Gold Mining Cap...    NEM
# 1     Shareholders v. Tesla, Nasdaq's diversity rule...   NDAQ
# 2     FedEx closing more locations, planning to furl...    FDX
# 3     Modelo Maker Profits From Bud Light‚Äôs De...    STZ
# 4     Med tech investors paying up for patents - Med...   ILMN
# ...                                                 ...    ...
# 1036  Lockheed Martin Stumbles on Supply Chain - WSJ...    LMT
# 4     product safety information product safety effe...
# ...                                                 ...
# 1036  product safety product safety important consid...
# 1037  factors credit analysis financial intermediari...
# 1038  greenhouse gas emissions rail transportation i...
# 1039  competitive behaviour open internet telecommun...
# 1040  product safety driving risky activity factors ...
#
#                                         query_embedding  \
# 0     [0.03913487493991852, 0.004532219842076302, 0....
# 1     [0.011969239450991154, -0.05236460268497467, -...
# 2     [0.042068369686603546, -0.03888951241970062, 0...
# 3     [0.05901496112346649, 0.011376441456377506, -0...
# 4     [0.008400478400290012, -0.03179089352488518, 0...
# ...                                                 ...
# 1036  [0.03700163587927818, -0.0315348319709301, -0....
# 1037  [0.07744689285755157, -0.0477789081633091, -0....
# 1038  [0.049445442855358124, -0.03318081423640251, 0...
# 1039  [0.012098213657736778, -0.012996641919016838, ...
# 1040  [0.006495227571576834, -0.0015140875475481153,...
#
#                                     candidate_embedding
# 0     [0.05467555671930313, -0.11273455619812012, 0....
# 1     [-0.025900591164827347, -0.028664009645581245,...
# 2     [0.06030776724219322, -0.12659691274166107, 0....
# 3     [0.03617096692323685, -0.036672115325927734, -...
# 4     [0.0538497194647789, -0.08131517469882965, 0.0...
# ...                                                 ...
# 1036  [-0.09254308044910431, -0.04089051112532616, 0...
# 1037  [0.0825621709227562, -0.11504682898521423, -0....
# 1038  [-0.00031995910103432834, -0.05394741520285606...
# 1039  [-0.04518311470746994, -0.04662075266242027, 0...
# 1040  [0.012432906776666641, -0.027485458180308342, ...
#
# [1041 rows x 22 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity
# Compute cosine similarity
similarity_scores = cosine_similarity(candidate_embeddings, query_embeddings)

# %%
similarity_scores
# Out:
# array([[0.40214288, 0.42126387, 0.31923607, ..., 0.31424257, 0.27241468,
#         0.24858631],
#        [0.28479084, 0.5311348 , 0.3055724 , ..., 0.33699417, 0.32223922,
#         0.32994804],
#        [0.20681112, 0.3036417 , 0.38422555, ..., 0.27731782, 0.21124437,
#         0.16820611],
#        ...,
#        [0.29766354, 0.30126536, 0.32963973, ..., 0.437491  , 0.1749703 ,
#         0.2810679 ],
#        [0.16222706, 0.28442267, 0.18814938, ..., 0.16412656, 0.26750275,
#         0.16986234],
#        [0.53071606, 0.37750873, 0.590927  , ..., 0.5144143 , 0.5996069 ,
#         0.6496229 ]], dtype=float32)

# %%
import numpy as np
# Extract the diagonal elements from the similarity_scores matrix
# These elements correspond to the cosine similarity between each query and its corresponding candidate
diagonal_similarity_scores = np.diag(similarity_scores)

# Add these scores as a new column in df_test
df_test['cosine_similarity_miniLM'] = diagonal_similarity_scores

# %%
df_test
# Out:
#                                       title_and_content Ticker  \
# 0     New York Cements Itself as the Gold Mining Cap...    NEM
# 1     Shareholders v. Tesla, Nasdaq's diversity rule...   NDAQ
# 2     FedEx closing more locations, planning to furl...    FDX
# 3     Modelo Maker Profits From Bud Light‚Äôs De...    STZ
# 4     Med tech investors paying up for patents - Med...   ILMN
# ...                                                 ...    ...
# 1036  Lockheed Martin Stumbles on Supply Chain - WSJ...    LMT
# 1037  Banks Rush To Borrow Record-Breaking $165 Bill...    BAC
# 1038  Ohio train derailment: Norfolk Southern CEO sa...    NSC
# 1038  [0.049445442855358124, -0.03318081423640251, 0...
# 1039  [0.012098213657736778, -0.012996641919016838, ...
# 1040  [0.006495227571576834, -0.0015140875475481153,...
#
#                                     candidate_embedding  \
# 0     [0.05467555671930313, -0.11273455619812012, 0....
# 1     [-0.025900591164827347, -0.028664009645581245,...
# 2     [0.06030776724219322, -0.12659691274166107, 0....
# 3     [0.03617096692323685, -0.036672115325927734, -...
# 4     [0.0538497194647789, -0.08131517469882965, 0.0...
# ...                                                 ...
# 1036  [-0.09254308044910431, -0.04089051112532616, 0...
# 1037  [0.0825621709227562, -0.11504682898521423, -0....
# 1038  [-0.00031995910103432834, -0.05394741520285606...
# 1039  [-0.04518311470746994, -0.04662075266242027, 0...
# 1040  [0.012432906776666641, -0.027485458180308342, ...
#
#      cosine_similarity_miniLM
# 0                    0.402143
# 1                    0.531135
# 2                    0.384226
# 3                    0.421684
# 4                    0.456808
# ...                       ...
# 1036                 0.347897
# 1037                 0.549043
# 1038                 0.437491
# 1039                 0.267503
# 1040                 0.649623
#
# [1041 rows x 23 columns]

# %%
df_test.to_csv('miniLM_output.csv')  # Optionally, save to a new CSV file

# %% [markdown]
# # Evaluation
#
# In this section after doing some additional model results prep work, we are computing the following metrics:
# * Success at K - A metric to establish whether we get a hit/relevant ESG article within K. Measures whether the relevant document (or item) appears in the top K positions of the model's ranking.
# * Mean Reciprocal Rank (MRR) - MRR provides insight into the model's ability to return relevant items at higher ranks. It measures when does the first relevant ESG article appears. The closer this final number is to 1, the better the system is at giving you the right answers upfront.
# * Precision at K - Measures the proportion of retrieved documents that are relevant among the top K documents retrieved. It's calculated by dividing the number of relevant documents in the top K by K.
# * Recall at K - Measures the proportion of relevant documents retrieved in the top K positions out of all relevant documents available.
# * F1 Score at K - Combines precision and recall into a single metric, offering a more comprehensive evaluation of the model's performance. It helps balance the trade-off between precision and recall, ensuring that neither is disproportionately favored.

# %%
df_test['GPT_ESG_or_not']
# Out:
# 0       Minor
# 1       Major
# 2       Minor
# 3       Minor
# 4       Minor
#         ...
# 1036    Major
# 1037    Major
# 1038    Major
# 1039    Major
# 1040    Major
# Name: GPT_ESG_or_not, Length: 1041, dtype: object

# %%
#PREP WORK FOR SUCCESS AT K
# Sort articles by cosine similarity score for each cw_sasb_query_text group
top_sorted_df = df_test.groupby('cw_sasb_query_text', group_keys=False) \
                  .apply(lambda x: x.sort_values('cosine_similarity_miniLM', ascending=False))
top_sorted_df = top_sorted_df.reset_index(drop=True)
test_df_relevant = df_test[['cw_text', 'GPT_ESG_or_not']].drop_duplicates()
merged_df_final = pd.merge(top_sorted_df, test_df_relevant, on='cw_text', how='left')

# %%
merged_df_final
# Out:
#                                       title_and_content Ticker  \
# 0     Top Ad Firm Suggests ‚ÄòPause‚Äô on Tw...    IPG
# 1     Ad industry tries to quash proposed data broke...    IPG
# 2     Advertisers pull back from Twitter amid 'uncer...    IPG
# 3     Credera launches global cross-functional AI co...    OMC
# 4     Michael Solomon Named CEO of PHD USA - NEW YOR...    OMC
# ...                                                 ...    ...
# 1040  "Violent" incidents are on the rise at Target ...    TGT
# 2     [0.017361894249916077, -0.03441184014081955, 0...
# 3     [0.0028907866217195988, -0.09370002150535583, ...
# 4     [0.017328303307294846, -0.03523758426308632, -...
# ...                                                 ...
# 1040  [0.015229632146656513, -0.0707889199256897, 0....
# 1041  [0.0041684615425765514, -0.09523602575063705, ...
# 1042  [0.005951021332293749, -0.06923587620258331, -...
# 1043  [-0.033035244792699814, -0.020411347970366478,...
# 1044  [-0.009735342115163803, -0.04179546236991882, ...
#
#      cosine_similarity_miniLM GPT_ESG_or_not_y
# 0                    0.589782            Major
# 1                    0.574550            Major
# 2                    0.540461            Major
# 3                    0.516890            Major
# 4                    0.509162            Minor
# ...                       ...              ...
# 1040                 0.402097            Major
# 1041                 0.371712            Minor
# 1042                 0.338688            Minor
# 1043                 0.263484            Minor
# 1044                 0.258609               No
#
# [1045 rows x 24 columns]

# %%
# Mapping - applying the Minor and Major as Yes assumption
mapping = {'Minor': 'Yes', 'Major': 'Yes', 'No': 'No'}
merged_df_final['GPT_ESG_or_not_x'] = merged_df_final['GPT_ESG_or_not_x'].map(mapping)
# Adding in the ground truth labels - checking if it was done successfullly
merged_df_final
# Out:
#                                       title_and_content Ticker  \
# 0     Top Ad Firm Suggests ‚ÄòPause‚Äô on Tw...    IPG
# 1     Ad industry tries to quash proposed data broke...    IPG
# 2     Advertisers pull back from Twitter amid 'uncer...    IPG
# 3     Credera launches global cross-functional AI co...    OMC
# 4     Michael Solomon Named CEO of PHD USA - NEW YOR...    OMC
# ...                                                 ...    ...
# 1040  "Violent" incidents are on the rise at Target ...    TGT
# 1041  Walmart earnings call foreshadows challenges a...    WMT
# 1042  Lowe's Cos. expands Triad footprint with distr...    LOW
# 1043  Dollar General cuts annual profit outlook on h...     DG
# 1044  Walmart Has Stumbled on a Great New Way to Mak...    WMT
#
#                                               Industry                Company  \
# 0                              Advertising & Marketing  Interpublic Group Cos
# 1                              Advertising & Marketing  Interpublic Group Cos
# 2                              Advertising & Marketing  Interpublic Group Cos
# 3                              Advertising & Marketing          Omnicom Group
# 4                              Advertising & Marketing          Omnicom Group
# ...                                                ...                    ...
# 1040  Multiline and Specialty Retailers & Distributors            Target Corp
# 1041  Multiline and Specialty Retailers & Distributors           Walmart Inc.
# 1042  Multiline and Specialty Retailers & Distributors         Lowe's Cos Inc
# 1043  Multiline and Specialty Retailers & Distributors    Dollar General Corp
# 1044  Multiline and Specialty Retailers & Distributors           Walmart Inc.
#
#                                                    SASB GPT_ESG_or_not_x  \
# 0     {'Advertising Integrity': 'Entities have a leg...              Yes
# 1     {'Advertising Integrity': 'Entities have a leg...              Yes
# 2     {'Advertising Integrity': 'Entities have a leg...              Yes
# 3     {'Advertising Integrity': 'Entities have a leg...              Yes
# 4     {'Advertising Integrity': 'Entities have a leg...              Yes
# ...                                                 ...              ...
# 1040  {'Workforce Diversity & Inclusion': 'The Multi...              Yes
# 1041  {'Workforce Diversity & Inclusion': 'The Multi...              Yes
# 1042  {'Workforce Diversity & Inclusion': 'The Multi...              Yes
# 1043  {'Workforce Diversity & Inclusion': 'The Multi...              Yes
# 1     ad industry tries quash proposed data broker r...
# 2     advertisers pull twitter amid uncertainty new ...
# 3     credera launches global cross functional ai co...
# 4     michael solomon named ceo phd usa new york 15 ...
# ...                                                 ...
# 1040  violent incidents rise target stores costing m...
# 1041  walmart earnings foreshadows challenges ahead ...
# 1042  lowe cos expands triad footprint distribution ...
# 1043  dollar general cuts annual profit outlook high...
# 1044  walmart stumbled great new way money know econ...
#
#                                      cw_sasb_query_text  \
# 0     advertising integrity entities legal responsib...
# 1     advertising integrity entities legal responsib...
# 2     advertising integrity entities legal responsib...
# 3     advertising integrity entities legal responsib...
# 4     advertising integrity entities legal responsib...
# ...                                                 ...
# 1040  workforce diversity inclusion multiline specia...
# 1041  workforce diversity inclusion multiline specia...
# 1042  workforce diversity inclusion multiline specia...
# 1043  workforce diversity inclusion multiline specia...
# 1044  workforce diversity inclusion multiline specia...
#
#                                         query_embedding  \
# 0     [0.011685706675052643, -0.08869925141334534, -...
# 1     [0.011685706675052643, -0.08869925141334534, -...
# 2     [0.011685706675052643, -0.08869925141334534, -...
# 3     [0.011685706675052643, -0.08869925141334534, -...
# 4     [0.011685706675052643, -0.08869925141334534, -...
# ...                                                 ...
# 1040  [0.044459979981184006, -0.03579284995794296, 0...
# 1041  [0.044459979981184006, -0.03579284995794296, 0...
# 1042  [0.044459979981184006, -0.03579284995794296, 0...
# 1043  [0.044459979981184006, -0.03579284995794296, 0...
# 1044  [0.044459979981184006, -0.03579284995794296, 0...
#
#                                     candidate_embedding  \
# 0     [0.0016523862723261118, -0.07466538995504379, ...
# 1     [-0.004404451698064804, -0.10143864899873734, ...
# 2     [0.017361894249916077, -0.03441184014081955, 0...
# 3     [0.0028907866217195988, -0.09370002150535583, ...
# 4     [0.017328303307294846, -0.03523758426308632, -...
# ...                                                 ...
# 1040  [0.015229632146656513, -0.0707889199256897, 0....
# 1041  [0.0041684615425765514, -0.09523602575063705, ...
# 1042  [0.005951021332293749, -0.06923587620258331, -...
# 1043  [-0.033035244792699814, -0.020411347970366478,...
# 1044  [-0.009735342115163803, -0.04179546236991882, ...
#
#      cosine_similarity_miniLM GPT_ESG_or_not_y
# 0                    0.589782            Major
# 1                    0.574550            Major
# 2                    0.540461            Major
# 3                    0.516890            Major
# 4                    0.509162            Minor
# ...                       ...              ...
# 1040                 0.402097            Major
# 1041                 0.371712            Minor
# 1042                 0.338688            Minor
# 1043                 0.263484            Minor
# 1044                 0.258609               No
#
# [1045 rows x 24 columns]

# %%
def calculate_success_at_k(merged_df, k):
    # Group by 'cw_sasb_query_text'
    grouped_df = merged_df.groupby('cw_sasb_query_text')
    group_sizes = grouped_df.size()
    hit_count = 0
    total_groups = len(grouped_df)
    for name, group in grouped_df:
        if 'Yes' in group.head(k)['GPT_ESG_or_not_x'].values:
            hit_count += 1
    hit_rate = hit_count / total_groups
    return hit_rate

# %%
#Call the function with merged_df_final and the value of k
# Initialize an empty DataFrame to store results
success_k = pd.DataFrame(columns=['k', 'hit_rate'])
# Create an empty list to store intermediate results
results = []
# Loop through k values from 1 to 5
for k in range(1, 6):
    hit_rate = calculate_success_at_k(merged_df_final, k)
    # Store the result as a dictionary in the list
    results.append({'k': k, 'hit_rate': hit_rate})

    # Convert the list of dictionaries to a DataFrame
success_k = pd.concat([pd.DataFrame([result]) for result in results], ignore_index=True)
# Display the results
print(success_k)
# Out:
#    k  hit_rate
# 0  1  0.869565
# 1  2  0.945652
# 2  3  0.956522
# 3  4  0.967391
# 4  5  0.978261

# %% [markdown]
# # MRR

# %%
def calculate_mrr(merged_df):
    # Group by 'cw_sasb_query_text' to process each query group separately
    grouped_df = merged_df.groupby('cw_sasb_query_text')
    total_queries = len(grouped_df)  # Total number of queries
    sum_reciprocal_rank = 0  # Initialize the sum of reciprocal ranks
    for name, group in grouped_df:
        # Sort each group just in case it's not sorted by relevance (similarity score)
        group = group.sort_values('cosine_similarity_miniLM', ascending=False)
        # Find the index (rank) of the first 'Yes' in the sorted group
        first_relevant_index = group['GPT_ESG_or_not_x'].eq('Yes').idxmax()
        if group.loc[first_relevant_index, 'GPT_ESG_or_not_x'] == 'Yes':
            rank = group.index.get_loc(first_relevant_index) + 1  # Get rank (1-based)
            sum_reciprocal_rank += 1 / rank  # Add the reciprocal of the rank to the sum
    mrr = sum_reciprocal_rank / total_queries  # Calculate the mean of the reciprocal ranks
    return mrr

# %%
# Call the function with your DataFrame and print the MRR
mrr_score = calculate_mrr(merged_df_final)
print(f"The Mean Reciprocal Rank (MRR) is: {mrr_score}")
# Out:
# The Mean Reciprocal Rank (MRR) is: 0.9170289855072463

# %%
def calculate_precision_recall_at_k_per_query(group, k):
    # Convert 'Yes'/'No' in 'GPT_ESG_or_not' to 1/0 for calculation
    group['is_correct'] = group['GPT_ESG_or_not_x'].apply(lambda x: 1 if x == 'Yes' else 0)
    # Sort the group by similarity_score in descending order and take top K
    top_k = group.sort_values('cosine_similarity_miniLM', ascending=False).head(k)
    # Calculate how many of the top K are correct
    correct_in_top_k = top_k['is_correct'].sum()
    # Calculate Precision at K
    precision_at_k = correct_in_top_k / k
    # Calculate Recall at K
    total_relevant = group['is_correct'].sum() #top_k['is_correct'].sum() #group['is_correct'].sum() #top_k['is_correct'].sum()
    recall_at_k = correct_in_top_k / total_relevant if total_relevant > 0 else 0 #k #total_relevant if total_relevant > 0 else 0
    # Calculate F1 at K
    if precision_at_k + recall_at_k > 0:
        f1_at_k = 2 * (precision_at_k * recall_at_k) / (precision_at_k + recall_at_k)
    else:
        f1_at_k = 0
    return precision_at_k, recall_at_k, f1_at_k

# %%
# Apply the function to each group and calculate the mean Precision, Recall, and F1 at K
# Use merged_df_final if want to see all of the initial test run results
results = merged_df_final.groupby('cw_sasb_query_text').apply(calculate_precision_recall_at_k_per_query, k=3)

# %%
# To see the overall average Precision, Recall, and F1 at K
average_precision_at_k = results.map(lambda x: x[0]).mean()
average_recall_at_k = results.map(lambda x: x[1]).mean()
average_f1_at_k = results.map(lambda x: x[2]).mean()
print(f"Average Precision at K: {average_precision_at_k}")
print(f"Average Recall at K: {average_recall_at_k}")
print(f"Average F1 at K: {average_f1_at_k}")
# Out:
# Average Precision at K: 0.7971014492753624
# Average Recall at K: 0.39725890769766
# Average F1 at K: 0.45564135905756903
